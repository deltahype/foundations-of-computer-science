# %% [markdown]
# You have to work on the files:
# *  [Books](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Books.csv.gz)
# *  [Book ratings](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Book-Ratings.csv.gz)
# *  [Users](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Users.csv.gz)
# *  [Goodbooks books](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks.csv.gz)
# *  [Goodbooks ratings](https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks-ratings.csv.gz)
#
# ### Notes
#
# 1.    It is mandatory to use GitHub for developing the project.
# 1.    The project must be a jupyter notebook.
# 1.    There is no restriction on the libraries that can be used, nor on the Python version.
# 1.    To read those files, you need to use the `encoding = 'latin-1'` option.
# 1.    All questions on the project **must** be asked in a public channel on [Zulip](https://focs.zulipchat.com), otherwise no  answer will be given.

# %%
import pandas as pd
import re
import numpy as np

# %%
Books = pd.read_csv('Books.csv', sep= ';', encoding= 'latin-1', low_memory= False)

# %%
Books_ratings = pd.read_csv('Book-Ratings.csv', sep= ';', encoding= 'latin-1' )

# %%
Users = pd.read_csv('Users.csv', sep= ';', encoding= 'latin-1')

# %%
Goodbooks= pd.read_csv('goodbooks.csv', encoding= 'latin-1')

# %%
Goodbooks_ratings= pd.read_csv('goodbooks-ratings.csv', encoding= 'latin-1')

# %%
Books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
Books.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
Books_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
Books_ratings.isna().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
Users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
Users.isna().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
Goodbooks.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
Goodbooks.isna().sum()
# Out:
# book_id                      0
# goodreads_book_id            0
# best_book_id                 0
# work_id                      0
# books_count                  0
# isbn                         0
# isbn13                       0
# authors                      0
# original_publication_year    0
# original_title               1
# title                        0
# language_code                1
# average_rating               0
# ratings_count                0
# work_ratings_count           0
# work_text_reviews_count      0
# ratings_1                    0
# ratings_2                    0
# ratings_3                    0
# ratings_4                    0
# ratings_5                    0
# image_url                    0
# small_image_url              0
# dtype: int64

# %%
Goodbooks_ratings.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
Goodbooks_ratings.isna().sum()
# Out:
# user_id    0
# book_id    0
# rating     0
# dtype: int64

# %% [markdown]
# ### 1. Normalize the location field of *Users* dataset, splitting into city, region, country.

# %%
compile1 = re.compile(r'^(?P<City>[^,]*),+\s*(?P<Region>[^,]*),+\s*(?P<Country>[^,]*)$')
# creo un'espressione regolare capace di discriminare tra stringhe che contengono al massimo tre parole divise tra loro 
# da una o più virgole ed uno o più spazi

# %%
Users[Users['Location'].str.contains(r'[A-Z]+')]  # controllo la presenza di maiuscole
# Out:
# Empty DataFrame
# Columns: [User-ID, Location, Age]
# Index: []

# %%
location3fields = Users[Users['Location'].str.contains(compile1) == True]
locationmessy = Users[Users['Location'].str.contains(compile1) == False]

#divido il dataset sulla base del contenuto della stringa relativa alla colonna 'location'
# Out:
# C:\universita\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\universita\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
len(location3fields) / len(Users) * 100

# La maggior parte del dataset rientra nel database location3fields
# Out:
# 99.56106692295003

# %%
location3fields[['City','Region','Country']] = location3fields['Location'].str.extract(compile1)
location3fields

#Creo le variabili City, Region e Country
# Out:
# C:\universita\Anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         User-ID                            Location   Age         City  \
# 0             1                  nyc, new york, usa   NaN          nyc
# 1             2           stockton, california, usa  18.0     stockton
# 2             3     moscow, yukon territory, russia   NaN       moscow
# 3             4           porto, v.n.gaia, portugal  17.0        porto
# 4             5  farnborough, hants, united kingdom   NaN  farnborough
# ...         ...                                 ...   ...          ...
# 278853   278854               portland, oregon, usa   NaN     portland
# 278854   278855  tacoma, washington, united kingdom  50.0       tacoma
# 278855   278856           brampton, ontario, canada   NaN     brampton
# 278856   278857           knoxville, tennessee, usa   NaN    knoxville
# 278857   278858                dublin, n/a, ireland   NaN       dublin
#
#                  Region         Country
# 0              new york             usa
# 1            california             usa
# 2       yukon territory          russia
# 3              v.n.gaia        portugal
# 4                 hants  united kingdom
# ...                 ...             ...
# 278853           oregon             usa
# 278854       washington  united kingdom
# 278855          ontario          canada
# 278856        tennessee             usa
# 278857              n/a         ireland
#
# [277634 rows x 6 columns]

# %%
locationmessy[['City','Region','Country']] = np.nan # assegno np.nan a quei pochi soggetti per i quali è impossibile agire senza controllare caso per caso
# Out:
# <ipython-input-22-99806e7f3b6d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locationmessy[['City','Region','Country']] = np.nan # assegno np.nan a quei pochi soggetti per i quali è impossibile agire senza controllare caso per caso
# C:\universita\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
UsersN = pd.concat([location3fields, locationmessy]) 
UsersN
# Out:
#         User-ID                                           Location   Age  \
# 0             1                                 nyc, new york, usa   NaN
# 1             2                          stockton, california, usa  18.0
# 2             3                    moscow, yukon territory, russia   NaN
# 3             4                          porto, v.n.gaia, portugal  17.0
# 4             5                 farnborough, hants, united kingdom   NaN
# ...         ...                                                ...   ...
# 277645   277646                            washington, dc, dc, usa  36.0
# 277717   277718          colorado springs, co 80901, colorado, usa  62.0
# 278028   278029  mansfield, nottinghamshire, england, united ki...  31.0
# 278214   278215                   nelson, motueka, nz, new zealand  28.0
# 278808   278809          norfolk, england, england, united kingdom  49.0
#
#                City           Region         Country
# 0               nyc         new york             usa
# 1          stockton       california             usa
# 2            moscow  yukon territory          russia
# 3             porto         v.n.gaia        portugal
# 4       farnborough            hants  united kingdom
# ...             ...              ...             ...
# 277645          NaN              NaN             NaN
# 277717          NaN              NaN             NaN
# 278028          NaN              NaN             NaN
# 278214          NaN              NaN             NaN
# 278808          NaN              NaN             NaN
#
# [278858 rows x 6 columns]

# %%
UsersN.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# City          1224
# Region        1224
# Country       1224
# dtype: int64

# %%
UsersN['City'] = UsersN['City'].str.replace(r'[^a-z ]+','', regex= True)
UsersN['Region']= UsersN['Region'].str.replace(r'[^a-z ]+','', regex= True)
UsersN['Country']= UsersN['Country'].str.replace(r'[^a-z ]+','', regex= True)
UsersN['City'] = UsersN['City'].str.replace(r'^\s+$','', regex= True)
UsersN['Region']= UsersN['Region'].str.replace(r'^\s+$','', regex= True)
UsersN['Country']= UsersN['Country'].str.replace(r'^\s+$','', regex= True)

# %%
UsersN.replace('', np.nan, inplace= True)   # trasformo le celle vuote in valori nulli
UsersN.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# City          1573
# Region        5016
# Country       5823
# dtype: int64

# %% [markdown]
# Controllo l'esistenza di celle prive di lettere.

# %%
UsersN[(UsersN['City'].str.contains(r'[a-z]+') == False)|(UsersN['Region'].str.contains(r'[a-z]+') == False)|(UsersN['Country'].str.contains(r'[a-z]+') == False)]
# Out:
# Empty DataFrame
# Columns: [User-ID, Location, Age, City, Region, Country]
# Index: []

# %%
UsersN.head(20)
# Out:
#     User-ID                                Location   Age            City  \
# 0         1                      nyc, new york, usa   NaN             nyc
# 1         2               stockton, california, usa  18.0        stockton
# 2         3         moscow, yukon territory, russia   NaN          moscow
# 3         4               porto, v.n.gaia, portugal  17.0           porto
# 4         5      farnborough, hants, united kingdom   NaN     farnborough
# 5         6           santa monica, california, usa  61.0    santa monica
# 6         7                     washington, dc, usa   NaN      washington
# 7         8                timmins, ontario, canada   NaN         timmins
# 8         9              germantown, tennessee, usa   NaN      germantown
# 9        10              albacete, wisconsin, spain  26.0        albacete
# 10       11          melbourne, victoria, australia  14.0       melbourne
# 11       12             fort bragg, california, usa   NaN      fort bragg
# 12       13             barcelona, barcelona, spain  26.0       barcelona
# 13       14                   mediapolis, iowa, usa   NaN      mediapolis
# 14       15                calgary, alberta, canada   NaN         calgary
# 15       16            albuquerque, new mexico, usa   NaN     albuquerque
# 16       17               chesapeake, virginia, usa   NaN      chesapeake
# 17       18  rio de janeiro, rio de janeiro, brazil  25.0  rio de janeiro
# 18       19                               weston, ,  14.0          weston
# 19       20            langhorne, pennsylvania, usa  19.0       langhorne
#
#              Region         Country
# 0          new york             usa
# 1        california             usa
# 2   yukon territory          russia
# 3            vngaia        portugal
# 4             hants  united kingdom
# 5        california             usa
# 6                dc             usa
# 7           ontario          canada
# 8         tennessee             usa
# 9         wisconsin           spain
# 10         victoria       australia
# 11       california             usa
# 12        barcelona           spain
# 13             iowa             usa
# 14          alberta          canada
# 15       new mexico             usa
# 16         virginia             usa
# 17   rio de janeiro          brazil
# 18              NaN             NaN
# 19     pennsylvania             usa

# %% [markdown]
# ### 2. For each book in the *Books* dataset, compute its average rating.

# %%
Books_and_ratings = pd.merge(Books, Books_ratings, on='ISBN', how= 'left')

# %%
Books_and_average = Books_and_ratings.groupby(['ISBN','Book-Title','Book-Author'], as_index=False)[['ISBN','Book-Title','Book-Author','Book-Rating']].mean()
Books_and_average.rename({'ISBN':'ISBN','Book-Title':'Book-Title','Book-Author':'Book-Author','Book-Rating':'Book-Average-Rating'}, axis='columns', inplace= True)
Books_and_average['Book-Average-Rating'] = round(Books_and_average['Book-Average-Rating'], ndigits= 1)
Books_and_average.head(15)
# Out:
#           ISBN                                         Book-Title  \
# 0   0000913154  The Way Things Work: An Illustrated Encycloped...
# 1   0001010565                                    Mog's Christmas
# 2   0001046438                                               Liar
# 3   0001046713                       Twopence to Cross the Mersey
# 4   000104687X  T.S. Eliot Reading \The Wasteland\" and Other ...
# 5   0001046934                      The Prime of Miss Jean Brodie
# 6   0001047213                                   The Fighting Man
# 7   0001047647                                 First Among Equals
# 8   0001047663                                   Matter Of Honour
# 9   0001047868                                          Kidnapped
# 10  0001047973                                    Brave New World
# 11  000104799X                                        Monk's-hood
# 12  0001048082                                    Made in America
# 13  0001048473                              Nothing Can Be Better
# 14  0001049879                             Daughters of the Storm
#
#                       Book-Author  Book-Average-Rating
# 0   C. van Amerongen (translator)                  8.0
# 1                     Judith Kerr                  0.0
# 2                     Stephen Fry                  9.0
# 3                 Helen Forrester                  0.0
# 4                      T.S. Eliot                  6.0
# 5                    Muriel Spark                  0.0
# 6                  Gerald Seymour                  9.0
# 7                  Jeffrey Archer                  0.0
# 8                  Jeffrey Archer                  0.0
# 9          Robert Louis Stevenson                  0.0
# 10                  Aldous Huxley                  9.0
# 11                   Ellis Peters                  7.5
# 12                    Bill Bryson                  8.0
# 13               Barns &amp; Budd                  0.0
# 14               Elizabeth Buchan                  0.0

# %% [markdown]
# ### 3. For each book in the *GoodBooks* dataset, compute its average rating.

# %%
# Il campo work_rating_count sembra essere una somma dei campi ratings(1,2,3,4,5). 
# Immagino che il suffisso numerico stia a indicare il voto della recensione
#Creo una nuova colonna average.
Goodbooks['average'] = ((Goodbooks['ratings_1'] * 1 )+(Goodbooks['ratings_2'] * 2 )+(Goodbooks['ratings_3'] * 3 )+(Goodbooks['ratings_4'] * 4 )+(Goodbooks['ratings_5'] * 5 ))/Goodbooks['work_ratings_count']
Goodbooks['average'] = round(Goodbooks['average'], ndigits= 1)

# %%
Goodbooks_and_average = Goodbooks.groupby(['book_id','isbn','original_title','title'], as_index= False)[['book_id','isbn','original_title','title','average']].mean()
Goodbooks_and_average.head(20)
# Out:
#           isbn                                     original_title  \
# 0    439023483                                   The Hunger Games
# 1    439554934           Harry Potter and the Philosopher's Stone
# 2    316015849                                           Twilight
# 3     61120081                              To Kill a Mockingbird
# 4    743273567                                   The Great Gatsby
# 5    525478817                             The Fault in Our Stars
# 6    618260307                 The Hobbit or There and Back Again
# 7    316769177                             The Catcher in the Rye
# 8   1416524797                                   Angels & Demons
# 9    679783261                                Pride and Prejudice
# 10  1594480001                                   The Kite Runner
# 11    62024035                                          Divergent
# 12   451524934                               Nineteen Eighty-Four
# 13   452284244                         Animal Farm: A Fairy Story
# 14   553296981  Het Achterhuis: Dagboekbrieven 14 juni 1942 - ...
# 15   307269752                             MÃ¤n som hatar kvinnor
# 16   439023491                                      Catching Fire
# 17  043965548X           Harry Potter and the Prisoner of Azkaban
# 18   618346252                         The Fellowship of the Ring
# 19   439023513                                         Mockingjay
#
#                                                 title  book_id  average
# 0             The Hunger Games (The Hunger Games, #1)        1      4.3
# 1   Harry Potter and the Sorcerer's Stone (Harry P...        2      4.4
# 2                             Twilight (Twilight, #1)        3      3.6
# 3                               To Kill a Mockingbird        4      4.3
# 4                                    The Great Gatsby        5      3.9
# 5                              The Fault in Our Stars        6      4.3
# 6                                          The Hobbit        7      4.2
# 7                              The Catcher in the Rye        8      3.8
# 8               Angels & Demons  (Robert Langdon, #1)        9      3.9
# 9                                 Pride and Prejudice       10      4.2
# 10                                    The Kite Runner       11      4.3
# 11                          Divergent (Divergent, #1)       12      4.2
# 12                                               1984       13      4.1
# 13                                        Animal Farm       14      3.9
# 14                          The Diary of a Young Girl       15      4.1
# 15   The Girl with the Dragon Tattoo (Millennium, #1)       16      4.1
# 16               Catching Fire (The Hunger Games, #2)       17      4.3
# 17  Harry Potter and the Prisoner of Azkaban (Harr...       18      4.5
# 18  The Fellowship of the Ring (The Lord of the Ri...       19      4.3
# 19                  Mockingjay (The Hunger Games, #3)       20      4.0

# %% [markdown]
# ### 4. Merge together all rows sharing the same book title, author and publisher. We will call the resulting datset `merged books`. The books that have not been merged together will not appear in `merged books`.

# %%
Groupby_books = Books.groupby(['Book-Title','Book-Author','Publisher'], as_index= False)['ISBN'].count()
merged_books = Groupby_books[Groupby_books['ISBN'] > 1]
merged_books.drop(['ISBN'], axis= 'columns', inplace= True)
# Out:
# C:\universita\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
merged_books.head(20)
# Out:
#                                              Book-Title  \
# 41                            !%@ (A Nutshell handbook)
# 59    'A Hell of a Place to Lose a Cow': An American...
# 255   10,000 dreams interpreted: A dictionary of dreams
# 465                                    101 Famous Poems
# 713                  15 Houseplants Even You Can't Kill
# 725                                  158 POUND MARRIAGE
# 741                       1700: Scenes from London Life
# 783   1921 : The Great Novel of the Irish Civil War ...
# 964                          2001. Odyssee im Weltraum.
# 1001                                  2010: Odyssey Two
# 1015                                2061: Odyssey Three
# 1017                              2095 (Time Warp Trio)
# 1031                                    21 Sugar Street
# 1068                                               24/7
# 1102                                         2ND COMING
# 1109                                         2nd Chance
# 1161    30 Days to Experiencing Spiritual Breakthroughs
# 1174                                         30 Seconds
# 1291                             365 Ways to Cook Pasta
# 1334                                         3rd Degree
#
#                   Book-Author                       Publisher
# 41              Donnalyn Frey                        O'Reilly
# 59                Tim Brookes             National Geographic
# 255   Gustavus Hindman Miller       Barnes &amp; Nobles Books
# 465               Roy J. Cook  McGraw-Hill/Contemporary Books
# 713                 Joe Elder               Berkley Pub Group
# 725               John Irving                          Pocket
# 741            Maureen Waller        Four Walls Eight Windows
# 783           Morgan Llywelyn                     Forge Books
# 964          Arthur C. Clarke                           Heyne
# 1001         Arthur C. Clarke                   Del Rey Books
# 1015         Arthur C. Clarke                   Del Rey Books
# 1017             Jon Scieszka                    Puffin Books
# 1031              Lynn Lauber         W W Norton &amp; Co Inc
# 1068                Jim Brown                Ballantine Books
# 1102             Walker Percy                          Pocket
# 1109          James Patterson                   Little, Brown
# 1161          Bruce Wilkinson                       Multnomah
# 1174                      Sam                    Warner Books
# 1291            Marie Simmons        HarperCollins Publishers
# 1334          James Patterson          Time Warner Audiobooks

# %% [markdown]
# ### 5. For each book in `merged books` compute its average rating.
#
# The average is computed considering all books in `books` that have been merged.

# %%
merged_books_and_info = pd.merge(merged_books, Books, on= ['Book-Title','Book-Author','Publisher'], how='left')
merged_books_and_info.head(20)
# Out:
#                                            Book-Title  \
# 0                           !%@ (A Nutshell handbook)
# 1                           !%@ (A Nutshell handbook)
# 2   'A Hell of a Place to Lose a Cow': An American...
# 3   'A Hell of a Place to Lose a Cow': An American...
# 4   10,000 dreams interpreted: A dictionary of dreams
# 5   10,000 dreams interpreted: A dictionary of dreams
# 6                                    101 Famous Poems
# 7                                    101 Famous Poems
# 8                                    101 Famous Poems
# 9                  15 Houseplants Even You Can't Kill
# 10                 15 Houseplants Even You Can't Kill
# 11                                 158 POUND MARRIAGE
# 12                                 158 POUND MARRIAGE
# 13                      1700: Scenes from London Life
# 14                      1700: Scenes from London Life
# 15  1921 : The Great Novel of the Irish Civil War ...
# 16  1921 : The Great Novel of the Irish Civil War ...
# 17                         2001. Odyssee im Weltraum.
# 18                         2001. Odyssee im Weltraum.
# 19                                  2010: Odyssey Two
#
#                 Book-Author                       Publisher        ISBN  \
# 0             Donnalyn Frey                        O'Reilly  1565920465
# 1             Donnalyn Frey                        O'Reilly  1565920317
# 2               Tim Brookes             National Geographic  0792276833
# 3               Tim Brookes             National Geographic  0792277295
# 4   Gustavus Hindman Miller       Barnes &amp; Nobles Books  1566196256
# 5   Gustavus Hindman Miller       Barnes &amp; Nobles Books  1566196264
# 6               Roy J. Cook  McGraw-Hill/Contemporary Books  0809288311
# 7               Roy J. Cook  McGraw-Hill/Contemporary Books  0809288346
# 8               Roy J. Cook  McGraw-Hill/Contemporary Books  0809250969
# 9                 Joe Elder               Berkley Pub Group  0425073696
# 10                Joe Elder               Berkley Pub Group  0425131300
# 11              John Irving                          Pocket  0671822535
# 12              John Irving                          Pocket  0671468111
# 13           Maureen Waller        Four Walls Eight Windows  1568582161
# 14           Maureen Waller        Four Walls Eight Windows  1568581645
# 15          Morgan Llywelyn                     Forge Books  0312867549
# 16          Morgan Llywelyn                     Forge Books  0812570790
# 17         Arthur C. Clarke                           Heyne  3453182618
# 18         Arthur C. Clarke                           Heyne  3453194381
# 19         Arthur C. Clarke                   Del Rey Books  0345303067
#
#    Year-Of-Publication                                        Image-URL-S  \
# 0                 1994  http://images.amazon.com/images/P/1565920465.0...
# 1                 1993  http://images.amazon.com/images/P/1565920317.0...
# 2                 2000  http://images.amazon.com/images/P/0792276833.0...
# 3                 2001  http://images.amazon.com/images/P/0792277295.0...
# 4                 1995  http://images.amazon.com/images/P/1566196256.0...
# 5                 1995  http://images.amazon.com/images/P/1566196264.0...
# 6                 1984  http://images.amazon.com/images/P/0809288311.0...
# 7                 1994  http://images.amazon.com/images/P/0809288346.0...
# 8                 1985  http://images.amazon.com/images/P/0809250969.0...
# 9                 1991  http://images.amazon.com/images/P/0425073696.0...
# 10                1991  http://images.amazon.com/images/P/0425131300.0...
# 11                1978  http://images.amazon.com/images/P/0671822535.0...
# 12                1982  http://images.amazon.com/images/P/0671468111.0...
# 13                2002  http://images.amazon.com/images/P/1568582161.0...
# 14                2000  http://images.amazon.com/images/P/1568581645.0...
# 15                2001  http://images.amazon.com/images/P/0312867549.0...
# 16                2002  http://images.amazon.com/images/P/0812570790.0...
# 17                2001  http://images.amazon.com/images/P/3453182618.0...
# 18                2001  http://images.amazon.com/images/P/3453194381.0...
# 19                1984  http://images.amazon.com/images/P/0345303067.0...
#
#                                           Image-URL-M  \
# 0   http://images.amazon.com/images/P/1565920465.0...
# 1   http://images.amazon.com/images/P/1565920317.0...
# 2   http://images.amazon.com/images/P/0792276833.0...
# 3   http://images.amazon.com/images/P/0792277295.0...
# 4   http://images.amazon.com/images/P/1566196256.0...
# 5   http://images.amazon.com/images/P/1566196264.0...
# 6   http://images.amazon.com/images/P/0809288311.0...
# 7   http://images.amazon.com/images/P/0809288346.0...
# 8   http://images.amazon.com/images/P/0809250969.0...
# 9   http://images.amazon.com/images/P/0425073696.0...
# 10  http://images.amazon.com/images/P/0425131300.0...
# 11  http://images.amazon.com/images/P/0671822535.0...
# 12  http://images.amazon.com/images/P/0671468111.0...
# 13  http://images.amazon.com/images/P/1568582161.0...
# 14  http://images.amazon.com/images/P/1568581645.0...
# 15  http://images.amazon.com/images/P/0312867549.0...
# 16  http://images.amazon.com/images/P/0812570790.0...
# 17  http://images.amazon.com/images/P/3453182618.0...
# 18  http://images.amazon.com/images/P/3453194381.0...
# 19  http://images.amazon.com/images/P/0345303067.0...
#
#                                           Image-URL-L
# 0   http://images.amazon.com/images/P/1565920465.0...
# 1   http://images.amazon.com/images/P/1565920317.0...
# 2   http://images.amazon.com/images/P/0792276833.0...
# 3   http://images.amazon.com/images/P/0792277295.0...
# 4   http://images.amazon.com/images/P/1566196256.0...
# 5   http://images.amazon.com/images/P/1566196264.0...
# 6   http://images.amazon.com/images/P/0809288311.0...
# 7   http://images.amazon.com/images/P/0809288346.0...
# 8   http://images.amazon.com/images/P/0809250969.0...
# 9   http://images.amazon.com/images/P/0425073696.0...
# 10  http://images.amazon.com/images/P/0425131300.0...
# 11  http://images.amazon.com/images/P/0671822535.0...
# 12  http://images.amazon.com/images/P/0671468111.0...
# 13  http://images.amazon.com/images/P/1568582161.0...
# 14  http://images.amazon.com/images/P/1568581645.0...
# 15  http://images.amazon.com/images/P/0312867549.0...
# 16  http://images.amazon.com/images/P/0812570790.0...
# 17  http://images.amazon.com/images/P/3453182618.0...
# 18  http://images.amazon.com/images/P/3453194381.0...
# 19  http://images.amazon.com/images/P/0345303067.0...

# %%
merged_books_and_info.drop(['Image-URL-S', 'Image-URL-M', 'Image-URL-L'], axis= 1, inplace= True)

# %%
merged_books_and_ratings = pd.merge(merged_books_and_info, Books_ratings, on='ISBN', how='left')
merged_books_and_average = merged_books_and_ratings.groupby(['Book-Title','Book-Author','Publisher','ISBN'], as_index=False)[['Book-Title','Book-Author','Publisher','ISBN','Book-Rating']].mean()
merged_books_and_average.rename({'Book-Title':'Book-Title','Book-Author':'Book-Author','Publisher':'Publisher','ISBN':'ISBN','Book-Rating': 'Book-Average'}, axis= 1, inplace= True)
merged_books_and_average.head(20)
# Out:
#                                            Book-Title  \
# 0                           !%@ (A Nutshell handbook)
# 1                           !%@ (A Nutshell handbook)
# 2   'A Hell of a Place to Lose a Cow': An American...
# 3   'A Hell of a Place to Lose a Cow': An American...
# 4   10,000 dreams interpreted: A dictionary of dreams
# 5   10,000 dreams interpreted: A dictionary of dreams
# 6                                    101 Famous Poems
# 7                                    101 Famous Poems
# 8                                    101 Famous Poems
# 9                  15 Houseplants Even You Can't Kill
# 10                 15 Houseplants Even You Can't Kill
# 11                                 158 POUND MARRIAGE
# 12                                 158 POUND MARRIAGE
# 13                      1700: Scenes from London Life
# 14                      1700: Scenes from London Life
# 15  1921 : The Great Novel of the Irish Civil War ...
# 16  1921 : The Great Novel of the Irish Civil War ...
# 17                         2001. Odyssee im Weltraum.
# 18                         2001. Odyssee im Weltraum.
# 19                                  2010: Odyssey Two
#
#                 Book-Author                       Publisher        ISBN  \
# 0             Donnalyn Frey                        O'Reilly  1565920317
# 1             Donnalyn Frey                        O'Reilly  1565920465
# 2               Tim Brookes             National Geographic  0792276833
# 3               Tim Brookes             National Geographic  0792277295
# 4   Gustavus Hindman Miller       Barnes &amp; Nobles Books  1566196256
# 5   Gustavus Hindman Miller       Barnes &amp; Nobles Books  1566196264
# 6               Roy J. Cook  McGraw-Hill/Contemporary Books  0809250969
# 7               Roy J. Cook  McGraw-Hill/Contemporary Books  0809288311
# 8               Roy J. Cook  McGraw-Hill/Contemporary Books  0809288346
# 9                 Joe Elder               Berkley Pub Group  0425073696
# 10                Joe Elder               Berkley Pub Group  0425131300
# 11              John Irving                          Pocket  0671468111
# 12              John Irving                          Pocket  0671822535
# 13           Maureen Waller        Four Walls Eight Windows  1568581645
# 14           Maureen Waller        Four Walls Eight Windows  1568582161
# 15          Morgan Llywelyn                     Forge Books  0312867549
# 16          Morgan Llywelyn                     Forge Books  0812570790
# 17         Arthur C. Clarke                           Heyne  3453182618
# 18         Arthur C. Clarke                           Heyne  3453194381
# 19         Arthur C. Clarke                   Del Rey Books  0345303067
#
#     Book-Average
# 0       6.000000
# 1       0.000000
# 2       0.000000
# 3       3.400000
# 4       7.250000
# 5       6.666667
# 6       0.000000
# 7       5.000000
# 8       4.333333
# 9       0.000000
# 10      0.000000
# 11      1.333333
# 12      3.500000
# 13      8.000000
# 14      4.500000
# 15      0.000000
# 16      2.000000
# 17      0.000000
# 18      9.000000
# 19      2.721519

# %% [markdown]
# ### 6. For each book in `merged books` compute the minimum and maximum of the average ratings over all corresponding books in the `books` dataset.
#
# Hence for each book in `merged books` we will have exactly two values (a minimum and a maximum)

# %%
merged_books_and_average_agg = merged_books_and_average.groupby(['Book-Title','Book-Author','Publisher']).agg({'Book-Average':[np.min, np.max, np.mean, 'count']})
merged_books_and_average_agg.head(15)
# Out:
#                                                                                                           Book-Average  \
#                                                                                                                   amin
# Book-Title                                         Book-Author             Publisher
# !%@ (A Nutshell handbook)                          Donnalyn Frey           O'Reilly                           0.000000
# 'A Hell of a Place to Lose a Cow': An American ... Tim Brookes             National Geographic                0.000000
# 10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller Barnes &amp; Nobles Books          6.666667
# 101 Famous Poems                                   Roy J. Cook             McGraw-Hill/Contemporary Books     0.000000
# 15 Houseplants Even You Can't Kill                 Joe Elder               Berkley Pub Group                  0.000000
# 158 POUND MARRIAGE                                 John Irving             Pocket                             1.333333
# 1700: Scenes from London Life                      Maureen Waller          Four Walls Eight Windows           4.500000
# 1921 : The Great Novel of the Irish Civil War (... Morgan Llywelyn         Forge Books                        0.000000
# 2001. Odyssee im Weltraum.                         Arthur C. Clarke        Heyne                              0.000000
# 2010: Odyssey Two                                  Arthur C. Clarke        Del Rey Books                      0.000000
# 2061: Odyssey Three                                Arthur C. Clarke        Del Rey Books                      3.209302
# 2095 (Time Warp Trio)                              Jon Scieszka            Puffin Books                       0.000000
# 21 Sugar Street                                    Lynn Lauber             W W Norton &amp; Co Inc            0.000000
# 24/7                                               Jim Brown               Ballantine Books                   2.700000
# 2ND COMING                                         Walker Percy            Pocket                             0.000000
#
#                                                                                                                      \
#                                                                                                                amax
# Book-Title                                         Book-Author             Publisher
# !%@ (A Nutshell handbook)                          Donnalyn Frey           O'Reilly                        6.000000
# 'A Hell of a Place to Lose a Cow': An American ... Tim Brookes             National Geographic             3.400000
# 10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller Barnes &amp; Nobles Books       7.250000
# 101 Famous Poems                                   Roy J. Cook             McGraw-Hill/Contemporary Books  5.000000
# 15 Houseplants Even You Can't Kill                 Joe Elder               Berkley Pub Group               0.000000
# 158 POUND MARRIAGE                                 John Irving             Pocket                          3.500000
# 1700: Scenes from London Life                      Maureen Waller          Four Walls Eight Windows        8.000000
# 1921 : The Great Novel of the Irish Civil War (... Morgan Llywelyn         Forge Books                     2.000000
# 2001. Odyssee im Weltraum.                         Arthur C. Clarke        Heyne                           9.000000
# 2010: Odyssey Two                                  Arthur C. Clarke        Del Rey Books                   2.721519
# 2061: Odyssey Three                                Arthur C. Clarke        Del Rey Books                   4.000000
# 2095 (Time Warp Trio)                              Jon Scieszka            Puffin Books                    5.000000
# 21 Sugar Street                                    Lynn Lauber             W W Norton &amp; Co Inc         7.000000
# 24/7                                               Jim Brown               Ballantine Books                3.714286
# 2ND COMING                                         Walker Percy            Pocket                          2.000000
#
#                                                                                                                      \
#                                                                                                                mean
# Book-Title                                         Book-Author             Publisher
# !%@ (A Nutshell handbook)                          Donnalyn Frey           O'Reilly                        3.000000
# 'A Hell of a Place to Lose a Cow': An American ... Tim Brookes             National Geographic             1.700000
# 10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller Barnes &amp; Nobles Books       6.958333
# 101 Famous Poems                                   Roy J. Cook             McGraw-Hill/Contemporary Books  3.111111
# 15 Houseplants Even You Can't Kill                 Joe Elder               Berkley Pub Group               0.000000
# 158 POUND MARRIAGE                                 John Irving             Pocket                          2.416667
# 1700: Scenes from London Life                      Maureen Waller          Four Walls Eight Windows        6.250000
# 1921 : The Great Novel of the Irish Civil War (... Morgan Llywelyn         Forge Books                     1.000000
# 2001. Odyssee im Weltraum.                         Arthur C. Clarke        Heyne                           4.500000
# 2010: Odyssey Two                                  Arthur C. Clarke        Del Rey Books                   1.360759
# 2061: Odyssey Three                                Arthur C. Clarke        Del Rey Books                   3.604651
# 2095 (Time Warp Trio)                              Jon Scieszka            Puffin Books                    2.500000
# 21 Sugar Street                                    Lynn Lauber             W W Norton &amp; Co Inc         3.500000
# 24/7                                               Jim Brown               Ballantine Books                3.207143
# 2ND COMING                                         Walker Percy            Pocket                          0.666667
#
#
#                                                                                                           count
# Book-Title                                         Book-Author             Publisher
# !%@ (A Nutshell handbook)                          Donnalyn Frey           O'Reilly                           2
# 'A Hell of a Place to Lose a Cow': An American ... Tim Brookes             National Geographic                2
# 10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller Barnes &amp; Nobles Books          2
# 101 Famous Poems                                   Roy J. Cook             McGraw-Hill/Contemporary Books     3
# 15 Houseplants Even You Can't Kill                 Joe Elder               Berkley Pub Group                  2
# 158 POUND MARRIAGE                                 John Irving             Pocket                             2
# 1700: Scenes from London Life                      Maureen Waller          Four Walls Eight Windows           2
# 1921 : The Great Novel of the Irish Civil War (... Morgan Llywelyn         Forge Books                        2
# 2001. Odyssee im Weltraum.                         Arthur C. Clarke        Heyne                              2
# 2010: Odyssey Two                                  Arthur C. Clarke        Del Rey Books                      2
# 2061: Odyssey Three                                Arthur C. Clarke        Del Rey Books                      2
# 2095 (Time Warp Trio)                              Jon Scieszka            Puffin Books                       2
# 21 Sugar Street                                    Lynn Lauber             W W Norton &amp; Co Inc            2
# 24/7                                               Jim Brown               Ballantine Books                   2
# 2ND COMING                                         Walker Percy            Pocket                             3

# %% [markdown]
# ### 7. For each book in `goodbooks`, compute the list of its authors. Assuming that the number of reviews with a text (column `work_text_reviews_count`) is split equally among all authors, find for each authors the total number of reviews with a text. We will call this quantity the *shared number of reviews with a text*.

# %%
Goodbooks_slim = Goodbooks[['authors','original_publication_year','title','average','work_text_reviews_count']]
Goodbooks_slim['authors'] = Goodbooks_slim['authors'].str.replace(r'^\s', '', regex= True)
# Out:
# <ipython-input-39-d8e45ead5b28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Goodbooks_slim['authors'] = Goodbooks_slim['authors'].str.replace(r'^\s', '', regex= True)

# %%
Goodbooks_slim['list_authors'] = Goodbooks_slim['authors'].str.split(r',\s')
Goodbooks_slim['number_authors'] = Goodbooks_slim['list_authors'].apply(lambda x: len(x))
Goodbooks_slim['text_reviews_per_author'] = round(Goodbooks_slim['work_text_reviews_count'] / Goodbooks_slim['number_authors'], ndigits= 2)
# Out:
# <ipython-input-40-0bcbeb53fff2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Goodbooks_slim['list_authors'] = Goodbooks_slim['authors'].str.split(r',\s')
# <ipython-input-40-0bcbeb53fff2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Goodbooks_slim['number_authors'] = Goodbooks_slim['list_authors'].apply(lambda x: len(x))
# <ipython-input-40-0bcbeb53fff2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Goodbooks_slim['text_reviews_per_author'] = round(Goodbooks_slim['work_text_reviews_count'] / Goodbooks_slim['number_authors'], ndigits= 2)

# %%
autore = []
for riga in Goodbooks_slim['list_authors']:
    for elemento in riga:
        if elemento not in autore:
            autore.append(elemento)
autore.sort()
autore
# Out:
# ['Alan R. Clarke',
#  'Aldous Huxley',
#  'Alice Sebold',
#  'Anne Frank',
#  'Antoine de Saint-ExupÃ©ry',
#  'Arthur Golden',
#  'Audrey Niffenegger',
#  'B.M. Mooyaart-Doubleday',
#  'Bernard Knox',
#  'Bram Stoker',
#  'C.S. Lewis',
#  'Cassandra Clare',
#  'CelÃ¢l Ã\x9cster',
#  'Charles Dickens',
#  'Charlotte BrontÃ«',
#  'Christopher Paolini',
#  'Dan Brown',
#  'David J. Skal',
#  'Dom Marcos Barbosa',
#  'Douglas Adams',
#  'E.B. White',
#  'E.L. James',
#  'E.V. Rieu',
#  'Eleanor Roosevelt',
#  'Elie Wiesel',
#  'Elizabeth Gilbert',
#  'Emily BrontÃ«',
#  'Erich Fromm',
#  'F. Scott Fitzgerald',
#  'Frances Hodgson Burnett',
#  'FrÃ©dÃ©ric Mugler',
#  'Gabriel GarcÃ\xada MÃ¡rquez',
#  'Garth Williams',
#  'George Orwell',
#  'George R.R. Martin',
#  'Gillian Flynn',
#  'Gregory Rabassa',
#  'Guy Cardwell',
#  'Hablot Knight Browne',
#  'Harper Lee',
#  'Helen Fielding',
#  'Homer',
#  'J.D. Salinger',
#  'J.K. Rowling',
#  'J.R.R. Tolkien',
#  'James Dashner',
#  'Jane Austen',
#  'Jeannette Walls',
#  'Jeffrey Eugenides',
#  'Jodi Picoult',
#  'John Green',
#  'John Grisham',
#  'John Seelye',
#  'John Steinbeck',
#  'Jon Krakauer',
#  'Kathryn Stockett',
#  'Khaled Hosseini',
#  'Kurt Vonnegut Jr.',
#  'Lauren Weisberger',
#  'Lois Lowry',
#  'Louis Sachar',
#  'Louisa May Alcott',
#  'Margaret Mitchell',
#  'Marion Wiesel',
#  'Mark Haddon',
#  'Mark Twain',
#  'Markus Zusak',
#  'Mary GrandPrÃ©',
#  'Mary Wollstonecraft Shelley',
#  'Maurice Hindle',
#  'Melina Karakosta',
#  'Michael Crichton',
#  'Michael Mason',
#  'Nicholas Sparks',
#  'Nina Auerbach',
#  'Orson Scott Card',
#  'Oscar Wilde',
#  'Paula Hawkins',
#  'Paulo Coelho',
#  'Percy Bysshe Shelley',
#  'Philip Pullman',
#  'Ray Bradbury',
#  'Reg Keeland',
#  'Richard Howard',
#  'Richard J. Dunn',
#  'Richard Maxwell',
#  'Rick Riordan',
#  'Robert           Jackson',
#  'Robert Fagles',
#  'Ros Ballaster',
#  'Rosemary Wells',
#  'Rufus Beck',
#  'S.E. Hinton',
#  'Sara Gruen',
#  'Shel Silverstein',
#  'Stephen Chbosky',
#  'Stephen J. Dubner',
#  'Stephen King',
#  'Stephenie Meyer',
#  'Steven D. Levitt',
#  'Stieg Larsson',
#  'Sue Monk Kidd',
#  'Suzanne Collins',
#  'Tony Tanner',
#  'Veronica Roth',
#  'William Golding',
#  'William Goldman',
#  'William Shakespeare',
#  'Yann Martel']

# %%
shared_review= np.zeros(109)
def shared_number_func(x):
    for i in range(len(autore) -1):
        if autore[i] in x['list_authors']:
            shared_review[i] = shared_review[i] + x['text_reviews_per_author']

# %%
Goodbooks_slim.apply(shared_number_func, axis= 1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 94    None
# 95    None
# 96    None
# 97    None
# 98    None
# Length: 99, dtype: object

# %%
shared_review
shared_number_of_reviews_with_a_text = list(shared_review)

# %%
len(shared_number_of_reviews_with_a_text)
# Out:
# 109

# %%
id_author = list(range(109))
len(id_author)
# Out:
# 109

# %%
Authors = pd.DataFrame(data={'id_author' : id_author,'author' : autore,'shared_number_of_reviews_with_a_text' : shared_number_of_reviews_with_a_text })
Authors.head(10)
# Out:
#    id_author                     author  shared_number_of_reviews_with_a_text
# 0          0             Alan R. Clarke                              27890.50
# 1          1              Aldous Huxley                              20095.00
# 2          2               Alice Sebold                              36642.00
# 3          3                 Anne Frank                               6941.67
# 4          4  Antoine de Saint-ExupÃ©ry                               6134.25
# 5          5              Arthur Golden                              25605.00
# 6          6         Audrey Niffenegger                              43382.00
# 7          7    B.M. Mooyaart-Doubleday                               6941.67
# 8          8               Bernard Knox                               1620.20
# 9          9                Bram Stoker                               5754.33

# %% [markdown]
# ### 8. For each year of publication, determine the author that has the largest value of the shared number of reviews with a text.

# %%
Goodbooks_year_sort = Goodbooks_slim.sort_values('original_publication_year')
Goodbooks_year_sort
# Out:
#                                               authors  \
# 78  Homer, Robert Fagles, E.V. Rieu, FrÃ©dÃ©ric Mu...
# 28      William Shakespeare, Robert           Jackson
# 75            Jane Austen, Tony Tanner, Ros Ballaster
# 9                                         Jane Austen
# 70  Mary Wollstonecraft Shelley, Percy Bysshe Shel...
# ..                                                ...
# 68                                      Veronica Roth
# 29                                      Gillian Flynn
# 95                                         E.L. James
# 5                                          John Green
# 60                                      Paula Hawkins
#
#     original_publication_year                                  title  average  \
# 78                     -720.0                            The Odyssey      3.7
# 28                     1595.0                       Romeo and Juliet      3.7
# 75                     1811.0                  Sense and Sensibility      4.1
# 9                      1813.0                    Pride and Prejudice      4.2
# 70                     1818.0                           Frankenstein      3.8
# ..                        ...                                    ...      ...
# 68                     2012.0              Insurgent (Divergent, #2)      4.1
# 29                     2012.0                              Gone Girl      4.0
# 95                     2012.0  Fifty Shades Freed (Fifty Shades, #3)      3.9
# 5                      2012.0                 The Fault in Our Stars      4.3
# 60                     2015.0                  The Girl on the Train      3.9
#
#     work_text_reviews_count  \
# 78                     8101
# 28                    14778
# 75                    11526
# 9                     49152
# 70                    19993
# ..                      ...
# 68                    55873
# 29                   121614
# 95                    25287
# 5                    140739
# 60                    93600
#
#                                          list_authors  number_authors  \
# 78  [Homer, Robert Fagles, E.V. Rieu, FrÃ©dÃ©ric M...               5
# 28    [William Shakespeare, Robert           Jackson]               2
# 75          [Jane Austen, Tony Tanner, Ros Ballaster]               3
# 9                                       [Jane Austen]               1
# 70  [Mary Wollstonecraft Shelley, Percy Bysshe She...               3
# ..                                                ...             ...
# 68                                    [Veronica Roth]               1
# 29                                    [Gillian Flynn]               1
# 95                                       [E.L. James]               1
# 5                                        [John Green]               1
# 60                                    [Paula Hawkins]               1
#
#     text_reviews_per_author
# 78                  1620.20
# 28                  7389.00
# 75                  3842.00
# 9                  49152.00
# 70                  6664.33
# ..                      ...
# 68                 55873.00
# 29                121614.00
# 95                 25287.00
# 5                 140739.00
# 60                 93600.00
#
# [99 rows x 8 columns]

# %%
max_shared_review = np.zeros([58, 109])
anni = list(Goodbooks_year_sort['original_publication_year'].unique())

def func_max_per_year(x): 
    for an in range(len(anni)):
        if x['original_publication_year'] == anni[an]: 
            for au in range(len(autore)):
                if autore[au] in x['list_authors']:
                      if x['text_reviews_per_author'] > max_shared_review[an,au]:
                        max_shared_review[an,au] = x['text_reviews_per_author']

# %%
Goodbooks_year_sort.apply(func_max_per_year, axis= 1)
# Out:
# 78    None
# 28    None
# 75    None
# 9     None
# 70    None
#       ...
# 68    None
# 29    None
# 95    None
# 5     None
# 60    None
# Length: 99, dtype: object

# %%
author_of_the_year = []
shared_number_of_reviews = []

for i in range(len(max_shared_review)):
    best_author_year = max_shared_review[i].argmax()
    author_of_the_year.append(autore[best_author_year])
    number_of_review = max_shared_review[i].max()
    shared_number_of_reviews.append(number_of_review)       
    
authors_of_the_year = pd.DataFrame(data= {'year': anni, 'author': author_of_the_year, 'shared_number_of_reviews': shared_number_of_reviews})
authors_of_the_year.tail(10)
# Out:
#       year           author  shared_number_of_reviews
# 48  2004.0     Jodi Picoult                   30719.0
# 49  2005.0  Stephenie Meyer                   95009.0
# 50  2006.0       Sara Gruen                   55732.0
# 51  2007.0  Cassandra Clare                   51589.0
# 52  2008.0  Suzanne Collins                  155254.0
# 53  2009.0  Suzanne Collins                   88538.0
# 54  2010.0  Suzanne Collins                   96274.0
# 55  2011.0    Veronica Roth                  101023.0
# 56  2012.0       John Green                  140739.0
# 57  2015.0    Paula Hawkins                   93600.0

# %% [markdown]
# ### 9. Assuming that there are no errors in the ISBN fields, find the books in both datasets, and compute the difference of average rating according to the ratings and the goodratings datasets

# %%
Books_intersection = pd.merge(Books_and_average,Goodbooks, left_on='ISBN', right_on='isbn')
Books_intersection
# Out:
#          ISBN                                         Book-Title  \
# 0  014028009X                              Bridget Jones's Diary
# 1  014038572X                      The Outsiders (Now in Speak!)
# 2  043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
# 3  1400032717  The Curious Incident of the Dog in the Night-T...
# 4  1594480001                                    The Kite Runner
#
#        Book-Author  Book-Average-Rating  book_id  goodreads_book_id  \
# 0   Helen Fielding                  3.8       75             227443
# 1     S. E. Hinton                  4.5       90             231804
# 2     J.K. Rowling                  3.5       18                  5
# 3      Mark Haddon                  4.8       60               1618
# 4  Khaled Hosseini                  2.4       11              77203
#
#    best_book_id  work_id  books_count        isbn  ...  work_ratings_count  \
# 0        227443  3185154          193  014028009X  ...              754498
# 1        231804  1426690          156  014038572X  ...              680437
# 2             5  2402163          376  043965548X  ...             1969375
# 3          1618  4259809          183  1400032717  ...              915790
# 4         77203  3295919          283  1594480001  ...             1878095
#
#   work_text_reviews_count  ratings_1 ratings_2 ratings_3 ratings_4  ratings_5  \
# 0                    8157      28973     59309    198555    254836     212825
# 1                   22662      10178     34346    134244    227250     274419
# 2                   36099       6716     20413    166129    509447    1266670
# 3                   35796      21049     58117    218218    355925     262481
# 4                   59730      34288     59980    226062    628174     929591
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1292060045m...
# 1  https://images.gr-assets.com/books/1442129426m...
# 2  https://images.gr-assets.com/books/1499277281m...
# 3  https://images.gr-assets.com/books/1479863624m...
# 4  https://images.gr-assets.com/books/1484565687m...
#
#                                      small_image_url  average
# 0  https://images.gr-assets.com/books/1292060045s...      3.7
# 1  https://images.gr-assets.com/books/1442129426s...      4.1
# 2  https://images.gr-assets.com/books/1499277281s...      4.5
# 3  https://images.gr-assets.com/books/1479863624s...      3.9
# 4  https://images.gr-assets.com/books/1484565687s...      4.3
#
# [5 rows x 28 columns]

# %%
Books_intersection['difference_between_ratings'] = Books_intersection['Book-Average-Rating'] - Books_intersection['average']
Books_intersection[['ISBN','Book-Title','Book-Author','Book-Average-Rating','average','difference_between_ratings']]
# Out:
#          ISBN                                         Book-Title  \
# 0  014028009X                              Bridget Jones's Diary
# 1  014038572X                      The Outsiders (Now in Speak!)
# 2  043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
# 3  1400032717  The Curious Incident of the Dog in the Night-T...
# 4  1594480001                                    The Kite Runner
#
#        Book-Author  Book-Average-Rating  average  difference_between_ratings
# 0   Helen Fielding                  3.8      3.7                         0.1
# 1     S. E. Hinton                  4.5      4.1                         0.4
# 2     J.K. Rowling                  3.5      4.5                        -1.0
# 3      Mark Haddon                  4.8      3.9                         0.9
# 4  Khaled Hosseini                  2.4      4.3                        -1.9

# %% [markdown]
# ### 10. Split the users dataset according to the age. One dataset contains the users with unknown age, one with age 0-14, one with age 15-24, one with age 25-34, and so on.

# %%
Users_age_sort = UsersN.set_index('Age').sort_index()
UsersNan = Users_age_sort.loc[np.nan]
Users0_14 = Users_age_sort.loc[0:14]
Users15_24 = Users_age_sort.loc[15:24]
Users25_34 = Users_age_sort.loc[25:34]
Users35_44 = Users_age_sort.loc[35:44]
Users45_54 = Users_age_sort.loc[45:54]
Users55_64 = Users_age_sort.loc[55:64]
Users65_74 = Users_age_sort.loc[65:74]
Users75_84 = Users_age_sort.loc[75:84]
Users85_94 = Users_age_sort.loc[85:94]
Users95_max = Users_age_sort.loc[95:119]

# %%
UsersNan.head(5)
# Out:
#      User-ID                            Location         City  \
# Age
# NaN        1                  nyc, new york, usa          nyc
# NaN        3     moscow, yukon territory, russia       moscow
# NaN        5  farnborough, hants, united kingdom  farnborough
# NaN        7                 washington, dc, usa   washington
# NaN        8            timmins, ontario, canada      timmins
#
#               Region         Country
# Age
# NaN         new york             usa
# NaN  yukon territory          russia
# NaN            hants  united kingdom
# NaN               dc             usa
# NaN          ontario          canada

# %%
Users0_14.head(5)
# Out:
#      User-ID                              Location        City         Region  \
# Age
# 0.0   162189  schÃ¶nebeck, sachsen-anhalt, germany   schnebeck  sachsenanhalt
# 0.0   275885       aveiro, beira litoral, portugal      aveiro  beira litoral
# 0.0   126963             richmond, california, usa    richmond     california
# 0.0    24507                     nice, n/a, france        nice             na
# 0.0   207002          west haven, connecticut, usa  west haven    connecticut
#
#       Country
# Age
# 0.0   germany
# 0.0  portugal
# 0.0       usa
# 0.0    france
# 0.0       usa

# %%
Users95_max.head(5)
# Out:
#       User-ID                             Location       City  \
# Age
# 95.0    75763                   austin, texas, usa     austin
# 96.0    13519                  miami, florida, usa      miami
# 96.0    44556                 tucson, arizona, usa     tucson
# 96.0   142329           am sueden, n/a, luxembourg  am sueden
# 97.0    35395  glenelg, south australia, australia    glenelg
#
#                Region     Country
# Age
# 95.0            texas         usa
# 96.0          florida         usa
# 96.0          arizona         usa
# 96.0               na  luxembourg
# 97.0  south australia   australia

# %% [markdown]
# ### 11. Find the books that appear only in the goodbooks datasets.

# %%
Goodbooks[~Goodbooks['isbn'].isin(Books['ISBN'])]
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         1            2767052       2767052   2792775          272
# 1         2                  3             3   4640799          491
# 2         3              41865         41865   3212258          226
# 3         4               2657          2657   3275794          487
# 4         5               4671          4671    245494         1356
# ..      ...                ...           ...       ...          ...
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13                                    authors  \
# 0    439023483  9.780439e+12                            Suzanne Collins
# 1    439554934  9.780440e+12               J.K. Rowling, Mary GrandPrÃ©
# 2    316015849  9.780316e+12                            Stephenie Meyer
# 3     61120081  9.780061e+12                                 Harper Lee
# 4    743273567  9.780743e+12                        F. Scott Fitzgerald
# ..         ...           ...                                        ...
# 94   375751513  9.780376e+12             Oscar Wilde, Jeffrey Eugenides
# 95   345803507  9.780346e+12                                 E.L. James
# 96   393970124  9.780394e+12  Bram Stoker, Nina Auerbach, David J. Skal
# 97   307269981  9.780307e+12                 Stieg Larsson, Reg Keeland
# 98  1612130585  9.781612e+12                                 E.L. James
#
#     original_publication_year                            original_title  ...  \
# 0                      2008.0                          The Hunger Games  ...
# 1                      1997.0  Harry Potter and the Philosopher's Stone  ...
# 2                      2005.0                                  Twilight  ...
# 3                      1960.0                     To Kill a Mockingbird  ...
# 4                      1925.0                          The Great Gatsby  ...
# ..                        ...                                       ...  ...
# 94                     1891.0                The Picture of Dorian Gray  ...
# 95                     2012.0                        Fifty Shades Freed  ...
# 96                     1897.0                                   Dracula  ...
# 97                     2006.0               Flickan som lekte med elden  ...
# 98                     2011.0                       Fifty Shades Darker  ...
#
#    work_ratings_count work_text_reviews_count  ratings_1  ratings_2  \
# 0             4942365                  155254      66715     127936
# 1             4800065                   75867      75504     101676
# 2             3916824                   95009     456191     436802
# 3             3340896                   72586      60427     117415
# 4             2773745                   51992      86236     197621
# ..                ...                     ...        ...        ...
# 94             674551                   19647       9825      30735
# 95             610116                   25287      39079      55691
# 96             689739                   17263      11756      36719
# 97             649253                   31423       4623      15781
# 98             623340                   28052      37245      58935
#
#     ratings_3  ratings_4  ratings_5  \
# 0      560092    1481305    2706317
# 1      455024    1156318    3011543
# 2      793319     875073    1355439
# 3      446835    1001952    1714267
# 4      606158     936012     947718
# ..        ...        ...        ...
# 94     129420     246892     257679
# 95     109963     140304     265079
# 96     151396     246043     243825
# 97      91021     258236     279592
# 98     114203     150906     262051
#
#                                             image_url  \
# 0   https://images.gr-assets.com/books/1447303603m...
# 1   https://images.gr-assets.com/books/1474154022m...
# 2   https://images.gr-assets.com/books/1361039443m...
# 3   https://images.gr-assets.com/books/1361975680m...
# 4   https://images.gr-assets.com/books/1490528560m...
# ..                                                ...
# 94  https://images.gr-assets.com/books/1424596966m...
# 95  https://images.gr-assets.com/books/1336418837m...
# 96  https://images.gr-assets.com/books/1387151694m...
# 97  https://images.gr-assets.com/books/1351778881m...
# 98  https://images.gr-assets.com/books/1358266080m...
#
#                                       small_image_url  average
# 0   https://images.gr-assets.com/books/1447303603s...      4.3
# 1   https://images.gr-assets.com/books/1474154022s...      4.4
# 2   https://images.gr-assets.com/books/1361039443s...      3.6
# 3   https://images.gr-assets.com/books/1361975680s...      4.3
# 4   https://images.gr-assets.com/books/1490528560s...      3.9
# ..                                                ...      ...
# 94  https://images.gr-assets.com/books/1424596966s...      4.1
# 95  https://images.gr-assets.com/books/1336418837s...      3.9
# 96  https://images.gr-assets.com/books/1387151694s...      4.0
# 97  https://images.gr-assets.com/books/1351778881s...      4.2
# 98  https://images.gr-assets.com/books/1358266080s...      3.9
#
# [94 rows x 24 columns]

# %% [markdown]
# ### 12. Assuming that each pair (author, title) identifies a book, for each book find the number of times it appears in the books dataset. Which books appear the most times?

# %%
Books.groupby(['Book-Title','Book-Author']).count().sort_values('ISBN', ascending= False).head(1)   # per la sorting va bene qualsiasi valore privo di nulli
# Out:
#                                 ISBN  Year-Of-Publication  Publisher  \
# Book-Title   Book-Author
# Little Women Louisa May Alcott    21                   21         21
#
#                                 Image-URL-S  Image-URL-M  Image-URL-L
# Book-Title   Book-Author
# Little Women Louisa May Alcott           21           21           21

# %% [markdown]
# ### 13. Find the author with the highest average rating according to the goodbooks datasets.

# %%
Goodbooks.groupby('authors', as_index= False)['average'].max().sort_values('average', ascending= False).head(1)
# Out:
#                          authors  average
# 30  J.K. Rowling, Mary GrandPrÃ©      4.6
